# %% [markdown]
# # DEM visualizations example

# %%
import sys
import arcpy
sys.path.append("../src")
from gdalUtils import GdalUtils
from utils import Utils
from plotter import PlotDEM

# %% [markdown]
# ## Plot DEM only

# %%
# dem_data = GdalUtils.read_raster()
dem_path = r"C:\Users\ageglio\Documents\NLM_DataRelease\Updated_DataRelease_Surfaces_NewProducts\BayHarbor\0.5m\BH_BY_0_5m_filled.tif"
plotter = PlotDEM(dem_path)
plotter.plot_dem(title="Depth Map", cmap="terrain", vmin=-35, vmax=0)

# %%
plotter.visualize_geomorphons(n_classes=10, save_fig=False, show=True)
# Out:
# Calculating 10-class Geomorphons...

# %%
plotter.analyze_geomorphon_data()
# Out:
# Calculating 10-class Geomorphons...

# %% [markdown]
# ## visualizing Local Binary Patterns

# %%
# Example usage demonstrating local binary product neighborhood cells:
plotter.plot_lbp_neighbors(n_points=21, radius=3)

# %%
n_points = 21
radius = 3
# Method can be 'uniform', 'nri_uniform', or 'ror'
# 'uniform' is the standard LBP method, 'nri_uniform' is for non-rotation invariant LBP, and 'ror' is for rotation invariant LBP.
method = 'uniform'  # or 'uniform', 'nri_uniform', 'ror'
# Generate LBP heatmap
plotter.generate_lbp_heatmap(n_points, radius, method=method, save_fig=False, show=True)
# Out:
# c:\Users\ageglio\AppData\Local\miniforge3\envs\arcpy3.4\Lib\site-packages\skimage\feature\texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(

# %% [markdown]
# ## Visualizing flow directions

# %%
# Example usage
plotter.generate_flow_heatmap()

# %% [markdown]
# ## Visualizing Shannon index

# %%
shannon_array = plotter.visualize_shannon_index(window_size=21)

# %% [markdown]
# ## Visualizing TPI, TRI, Roughness, Slope, Aspect

# %%
variable = "TRI"  # Options: "Roughness", "Slope", "Aspect", "Hillshade", "TPI", "TRI"
plotter.generate_tpi_tri_roughness_slope_aspect_heatmap(variable, save_fig=False, show=True)
